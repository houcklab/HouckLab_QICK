# %%
# %matplotlib widget

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
file =  open(r'Z:\t1Team\Data\2024-02-29_BFG_cooldown\2024-02-25_TAHP02_Au+144nm\wide_sweep_-2024-03-08-17-32-24.pickle', 'rb')
data = pickle.load(file)

# %%
fig,ax = plt.subplots()
ax.scatter(data['data']['f'],data['data']['ampArray_log'],marker='.',s=2)
ax.set_xlabel('Frequency (MHz)')
# Out:
# Text(0.5, 0, 'Frequency (MHz)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
