# %%
# %matplotlib widget

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
file =  open(r'Z:\t1Team\Data\2024-04-22_BFE_cooldown\2024-04-18_TAHP02_liftoff_Nb-Au_04\rfsoc\dump\wide_sweep-2024-04-25-15-07-30.pickle', 'rb')
data = pickle.load(file)

# %%
fig,ax = plt.subplots(1,1)
ax.scatter(data['data']['f'],data['data']['ampArray_log'],marker='.',s=2)
ax.set_xlabel('Frequency (MHz)')

# ax[1].scatter(data['data']['f'],data['data']['phaseArray'],marker='.',s=2)
# ax[1].set_xlabel('Frequency (MHz)')
# Out:
# Text(0.5, 0, 'Frequency (MHz)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
