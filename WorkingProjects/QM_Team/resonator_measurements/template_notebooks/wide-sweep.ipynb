# %%
# %matplotlib widget

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
file =  open(r'Z:\t1Team\Data\2024-04-19_cooldown\2024-04-15_TAHP02_Al2O3_Ta-Au-300nm_01\dump\wide_sweep_-2024-04-20-12-26-54.pickle', 'rb')
data = pickle.load(file)

# %%
print(np.size(np.diff(data['data']['ampArray_log'])))
print(np.size(np.concatenate(data['data']['f'])[:-1]))
# Out:
# 2999998
# 2999999

# %%
fig,ax = plt.subplots()
ax.scatter(data['data']['f'],data['data']['ampArray_log'],marker='.',s=2)
ax.set_xlabel('Frequency (MHz)')
# Out:
# Text(0.5, 0, 'Frequency (MHz)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax = plt.subplots()
ax.scatter(np.concatenate(data['data']['f'])[:-2],np.diff(data['data']['ampArray_log']),marker='.',s=2)
ax.set_xlabel('Frequency (MHz)')
# Out:
# Text(0.5, 0, 'Frequency (MHz)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
