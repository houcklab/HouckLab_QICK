# %%
# !which pip
# Out:
# /usr/local/share/pynq-venv/bin/pip

# %%
# !pip list installed
# Out:
# Package                           Version
# --------------------------------- --------------
# 2ping                             4.3
# alabaster                         0.7.12
# anyio                             3.1.0
# argon2-cffi                       20.1.0
# async-generator                   1.10
# atomicwrites                      1.1.5
# attrs                             19.3.0
# Babel                             2.9.1
# backcall                          0.2.0
# beautifulsoup4                    4.8.2
# bleach                            3.3.0
# blinker                           1.4
# blosc                             1.7.0
# Brotli                            1.0.9
# certifi                           2019.11.28
# cffi                              1.14.5
# chardet                           3.0.4
# click                             8.0.1
# cloudpickle                       1.3.0
# CppHeaderParser                   2.7.4
# cryptography                      2.8
# ...

# %%
# !pip install /home/xilinx/jupyter_notebooks/qick
# Out:
# Processing /home/xilinx/jupyter_notebooks/qick
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for qick: filename=qick-1.0.0-py3-none-any.whl size=10953397 sha256=d90651c2074ed3ef0afe3903e4b32efd2cd32804287785ad94206abb0b030c02
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c8fdmxis/wheels/e0/a4/f0/c50d7d0303d9e675fe0c41e501aa680926d61e981c95ad65e0
# Successfully built qick
# ...

# %%
# !pip show qick
# Out:
# Name: qick
# Version: 1.0.0
# Summary: Quantum Instrumentation Controller Kit software library
# Home-page: https://github.com/openquantumhardware/qick
# Author: Open Quantum Hardware
# Author-email: openquantumhardware@gmail.com
# License: UNKNOWN
# Location: /usr/local/share/pynq-venv/lib/python3.8/site-packages
# Requires: pynq, tqdm, numpy
# Required-by:

# %%
# !pip uninstall -y qick
# Out:
# WARNING: Skipping qick as it is not installed.

# %%
# !pip install -e /home/xilinx/jupyter_notebooks/qick
# Out:
# Obtaining file:///home/xilinx/jupyter_notebooks/qick
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#   Running setup.py develop for qick
# ...
# WARNING: You are using pip version 21.2.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/share/pynq-venv/bin/python3 -m pip install --upgrade pip' command.
